# %%
# pip install sparqlwrapper
# https://rdflib.github.io/sparqlwrapper/

import sys
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
import requests

# %%
endpoint_url = "https://query.wikidata.org/sparql"

query = """SELECT ?fish ?fishLabel ?wormsLabel ?pic
WHERE {
  # ?fish wdt:P171* wd:Q27207.
  # ?fish wdt:P105 wd:Q7432.
  # ?fish wdt:P850 ?worms.
  # ?fish wdt:P18 ?pic.
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
}
LIMIT 100
"""

# %%
def get_results(endpoint_url, query):
    user_agent = "WDQS-example Python/%s.%s" % (
        sys.version_info[0],
        sys.version_info[1],
    )
    # TODO adjust user agent; see https://w.wiki/CX6
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()

# %%
results = get_results(endpoint_url, query)

# %%
for row in results["results"]["bindings"]:
    for key in row:
        row[key] = row[key]["value"]

# %%
df = pd.DataFrame.from_dict(results["results"]["bindings"])

# %%
df
# Out:
#                                        fish  \
# 0   http://www.wikidata.org/entity/Q1887880
# 1   http://www.wikidata.org/entity/Q1901712
# 2   http://www.wikidata.org/entity/Q1954812
# 3   http://www.wikidata.org/entity/Q1954812
# 4   http://www.wikidata.org/entity/Q2078547
# ..                                      ...
# 95  http://www.wikidata.org/entity/Q1687707
# 96  http://www.wikidata.org/entity/Q1812367
# 97  http://www.wikidata.org/entity/Q2002023
# 98  http://www.wikidata.org/entity/Q2606177
# 99  http://www.wikidata.org/entity/Q3546845
#
#                                                   pic  \
# 0   http://commons.wikimedia.org/wiki/Special:File...
# 1   http://commons.wikimedia.org/wiki/Special:File...
# 2   http://commons.wikimedia.org/wiki/Special:File...
# 3   http://commons.wikimedia.org/wiki/Special:File...
# 4   http://commons.wikimedia.org/wiki/Special:File...
# ..                                                ...
# 95  http://commons.wikimedia.org/wiki/Special:File...
# 96  http://commons.wikimedia.org/wiki/Special:File...
# 97  http://commons.wikimedia.org/wiki/Special:File...
# 98  http://commons.wikimedia.org/wiki/Special:File...
# 99  http://commons.wikimedia.org/wiki/Special:File...
#
#                      fishLabel wormsLabel
# 0       Sixspine leatherjacket     220060
# 1         Smooth leatherjacket     277614
# 2         Monacanthus ciliatus     159497
# 3         Monacanthus ciliatus     159497
# 4             Slender Filefish     159499
# ..                         ...        ...
# 95          Buenos Aires tetra    1016061
# 96   Hyphessobrycon peruvianus    1014975
# 97  Hyphessobrycon columbianus    1384285
# 98                  Clown barb    1461347
# 99      Hyphessobrycon bentosi    1013917
#
# [100 rows x 4 columns]

# %%
WORMS_BASE_URL = "https://www.marinespecies.org/rest/"
ATTRIBUTE_BY_ID = "AphiaAttributesByAphiaID/{id}"

# %%
enrichment = []

for i in range(len(df)):
    aphiaId = df.iloc[i]["wormsLabel"]
    res = requests.get(url=WORMS_BASE_URL + ATTRIBUTE_BY_ID.format(id=aphiaId))
    try:
        res.raise_for_status()
        for data in res.json():

            enrichment.append(data)
    except:
        print(f"AphiaId {df.iloc[i]["wormsLabel"]} failed to fetch")
# Out:
# AphiaId 1476251 failed to fetch
# AphiaId 1476251 failed to fetch
# AphiaId 1016061 failed to fetch
# AphiaId 1461347 failed to fetch

# %%
worms_df = pd.DataFrame.from_dict(enrichment).set_index(
    ["AphiaID", "measurementTypeID"]
)

# %%
worms_df
# Out:
#                                                             measurementType  \
# AphiaID measurementTypeID
# 220060  15                                                        Body size
#         144                Species exhibits underwater soniferous behaviour
#         23                                    Species importance to society
# 277614  23                                    Species importance to society
#         15                                                        Body size
# ...                                                                     ...
# 1014975 23                                    Species importance to society
# 1384285 144                Species exhibits underwater soniferous behaviour
#         23                                    Species importance to society
# 1013917 144                Species exhibits underwater soniferous behaviour
#         23                                    Species importance to society
#
#                                                             measurementValue  \
# AphiaID measurementTypeID
# 220060  15                                                                60
#         144                Likely to produce sound under natural conditio...
#         23                                                     IUCN Red List
# 277614  23                 FAO-ASFIS: Species for Fishery Statistics Purp...
#         15                                                                31
# ...                                                                      ...
# 1014975 23                                                     IUCN Red List
# 1384285 144                Likely to produce sound under natural conditio...
#         23                                                     IUCN Red List
# 1013917 144                Likely to produce sound under natural conditio...
#         23                                                     IUCN Red List
#
#                            source_id  \
# AphiaID measurementTypeID
# 220060  15                    232813
#         144                   452075
#         23                    127093
# 277614  23                    197354
#         15                    232813
# ...                              ...
# 1014975 23                    127093
# 1384285 144                   452075
#         23                    127093
# 1013917 144                   452075
#         23                    127093
#
#                                                                    reference  \
# AphiaID measurementTypeID
# 220060  15                 May, J.L.; Maxwell, J.G.H. (1986). Trawl fish ...
#         144                Rice, A. N.; Farina, S. C.; Makowski, A. J.; K...
#         23                               IUCN Red List of Threatened Species
# 277614  23                 FAO Fishery Fact Sheets Collections: Aquatic S...
#         15                 May, J.L.; Maxwell, J.G.H. (1986). Trawl fish ...
# ...                                                                      ...
# 1014975 23                               IUCN Red List of Threatened Species
# 1384285 144                Rice, A. N.; Farina, S. C.; Makowski, A. J.; K...
#         23                               IUCN Red List of Threatened Species
# 1013917 144                Rice, A. N.; Farina, S. C.; Makowski, A. J.; K...
#         23                               IUCN Red List of Threatened Species
#
#                           qualitystatus  AphiaID_Inherited  CategoryID  \
# AphiaID measurementTypeID
# 220060  15                      checked             220060         NaN
#         144                  unreviewed             220060        55.0
#         23                   unreviewed             220060        13.0
# 277614  23                   unreviewed             320098        13.0
#         15                      checked             277614         NaN
# ...                                 ...                ...         ...
# 1014975 23                   unreviewed            1014975        13.0
# 1384285 144                  unreviewed            1384285        55.0
#         23                   unreviewed            1384285        13.0
# 1013917 144                  unreviewed            1013917        55.0
#         23                   unreviewed            1013917        13.0
#
#                                                                     children
# AphiaID measurementTypeID
# 220060  15                 [{'AphiaID': '220060', 'measurementTypeID': 17...
#         144                                                               []
#         23                 [{'AphiaID': '220060', 'measurementTypeID': 1,...
# 277614  23                 [{'AphiaID': '277614', 'measurementTypeID': 24...
#         15                 [{'AphiaID': '277614', 'measurementTypeID': 17...
# ...                                                                      ...
# 1014975 23                 [{'AphiaID': '1014975', 'measurementTypeID': 1...
# 1384285 144                                                               []
#         23                 [{'AphiaID': '1384285', 'measurementTypeID': 1...
# 1013917 144                                                               []
#         23                 [{'AphiaID': '1013917', 'measurementTypeID': 1...
#
# [247 rows x 8 columns]

# %%
worms_df["measurementType"].unique()
# Out:
# array(['Body size', 'Species exhibits underwater soniferous behaviour',
#        'Species importance to society'], dtype=object)

# %%
df.merge(worms_df, left_on="wormsLabel", right_on="AphiaID").drop(columns=["wormsLabel"])
# Out:
#                                         fish  \
# 0    http://www.wikidata.org/entity/Q1887880
# 1    http://www.wikidata.org/entity/Q1887880
# 2    http://www.wikidata.org/entity/Q1887880
# 3    http://www.wikidata.org/entity/Q1901712
# 4    http://www.wikidata.org/entity/Q1901712
# ..                                       ...
# 292  http://www.wikidata.org/entity/Q1812367
# 293  http://www.wikidata.org/entity/Q2002023
# 294  http://www.wikidata.org/entity/Q2002023
# 295  http://www.wikidata.org/entity/Q3546845
# 296  http://www.wikidata.org/entity/Q3546845
#
#                                                    pic  \
# 0    http://commons.wikimedia.org/wiki/Special:File...
# 1    http://commons.wikimedia.org/wiki/Special:File...
# 2    http://commons.wikimedia.org/wiki/Special:File...
# 3    http://commons.wikimedia.org/wiki/Special:File...
# 4    http://commons.wikimedia.org/wiki/Special:File...
# ..                                                 ...
# 292  http://commons.wikimedia.org/wiki/Special:File...
# 293  http://commons.wikimedia.org/wiki/Special:File...
# 294  http://commons.wikimedia.org/wiki/Special:File...
# 295  http://commons.wikimedia.org/wiki/Special:File...
# 296  http://commons.wikimedia.org/wiki/Special:File...
#
#                       fishLabel  \
# 0        Sixspine leatherjacket
# 1        Sixspine leatherjacket
# 2        Sixspine leatherjacket
# 3          Smooth leatherjacket
# 4          Smooth leatherjacket
# ..                          ...
# 292   Hyphessobrycon peruvianus
# 293  Hyphessobrycon columbianus
# 294  Hyphessobrycon columbianus
# 295      Hyphessobrycon bentosi
# 296      Hyphessobrycon bentosi
#
#                                       measurementType  \
# 0                                           Body size
# 1    Species exhibits underwater soniferous behaviour
# 2                       Species importance to society
# 3                       Species importance to society
# 4                                           Body size
# ..                                                ...
# 292                     Species importance to society
# 293  Species exhibits underwater soniferous behaviour
# 294                     Species importance to society
# 295  Species exhibits underwater soniferous behaviour
# 296                     Species importance to society
#
#                                       measurementValue  source_id  \
# 0                                                   60     232813
# 1    Likely to produce sound under natural conditio...     452075
# 2                                        IUCN Red List     127093
# 3    FAO-ASFIS: Species for Fishery Statistics Purp...     197354
# 4                                                   31     232813
# ..                                                 ...        ...
# 292                                      IUCN Red List     127093
# 293  Likely to produce sound under natural conditio...     452075
# 294                                      IUCN Red List     127093
# 295  Likely to produce sound under natural conditio...     452075
# 296                                      IUCN Red List     127093
#
#                                              reference qualitystatus  \
# 0    May, J.L.; Maxwell, J.G.H. (1986). Trawl fish ...       checked
# 1    Rice, A. N.; Farina, S. C.; Makowski, A. J.; K...    unreviewed
# 2                  IUCN Red List of Threatened Species    unreviewed
# 3    FAO Fishery Fact Sheets Collections: Aquatic S...    unreviewed
# 4    May, J.L.; Maxwell, J.G.H. (1986). Trawl fish ...       checked
# ..                                                 ...           ...
# 292                IUCN Red List of Threatened Species    unreviewed
# 293  Rice, A. N.; Farina, S. C.; Makowski, A. J.; K...    unreviewed
# 294                IUCN Red List of Threatened Species    unreviewed
# 295  Rice, A. N.; Farina, S. C.; Makowski, A. J.; K...    unreviewed
# 296                IUCN Red List of Threatened Species    unreviewed
#
#      AphiaID_Inherited  CategoryID  \
# 0               220060         NaN
# 1               220060        55.0
# 2               220060        13.0
# 3               320098        13.0
# 4               277614         NaN
# ..                 ...         ...
# 292            1014975        13.0
# 293            1384285        55.0
# 294            1384285        13.0
# 295            1013917        55.0
# 296            1013917        13.0
#
#                                               children
# 0    [{'AphiaID': '220060', 'measurementTypeID': 17...
# 1                                                   []
# 2    [{'AphiaID': '220060', 'measurementTypeID': 1,...
# 3    [{'AphiaID': '277614', 'measurementTypeID': 24...
# 4    [{'AphiaID': '277614', 'measurementTypeID': 17...
# ..                                                 ...
# 292  [{'AphiaID': '1014975', 'measurementTypeID': 1...
# 293                                                 []
# 294  [{'AphiaID': '1384285', 'measurementTypeID': 1...
# 295                                                 []
# 296  [{'AphiaID': '1013917', 'measurementTypeID': 1...
#
# [297 rows x 11 columns]
